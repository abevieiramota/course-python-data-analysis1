# %%
import pandas as pd
from datetime import datetime
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

from matplotlib import rcParams

rcParams["figure.figsize"] = (6, 6)

# %% [markdown]
# Wrappers para métodos do matplotlib.

# %% [markdown]
# # Line

# %%
ts = pd.DataFrame(np.random.randn(1000, 4), 
               index=pd.date_range("1/1/2015", periods=1000),
               columns=list("ABCD"))
ts = ts.cumsum()
ts.plot.line(figsize=(10, 6))

# %% [markdown]
# # Bar/Barh

# %%
tts = ts.sum()

tts
# Out:
# A    20461.587287
# B    13789.259542
# C   -14941.961541
# D     1703.889170
# dtype: float64

# %%
tts.plot.bar()
# linha horizontal, na posição 0, cor blacK
plt.axhline(0, color='k')

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=list('abcd'))

df
# Out:
#           a         b         c         d
# 0  0.528855  0.856473  0.597243  0.858316
# 1  0.224930  0.880400  0.306036  0.198370
# 2  0.509446  0.471142  0.934288  0.173695
# 3  0.417879  0.964772  0.167538  0.286318
# 4  0.169456  0.997869  0.505556  0.808162
# 5  0.330287  0.314914  0.859853  0.022303
# 6  0.359601  0.020825  0.820441  0.209867
# 7  0.060859  0.882784  0.035113  0.402535
# 8  0.555193  0.004191  0.494731  0.608161
# 9  0.481421  0.647467  0.079720  0.175747

# %%
df.plot.bar(figsize=(10, 6))

# %%
df.plot.bar(stacked=True)

# %%
df.plot.barh(stacked=True)

# %%
df.div(df.sum(axis=1), axis=0).plot.barh(stacked=True)
plt.legend(bbox_to_anchor=(1., .5))

# %% [markdown]
# # Histogram

# %%
df = pd.DataFrame({'a': np.random.randn(1000) + 1,
                   'b': np.random.randn(1000),
                   'c': np.random.randn(1000) - 1})

df.plot.hist(alpha=.5)

# %%
df.plot.hist(stacked=True, bins=20)

# %% [markdown]
# # Boxplot

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=list('abcde'))

df.plot.box()

# %%
df.plot.box(vert=False)

# %% [markdown]
# # Pie

# %%
s = pd.Series(3 * np.random.rand(4), index=list('abcd'))
s
# Out:
# a    2.311359
# b    1.235981
# c    1.106288
# d    2.069940
# dtype: float64

# %%
s.plot.pie(autopct="%.2f")

# %% [markdown]
# # Scatter

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=list('abcd'))
df.head()
# Out:
#           a         b         c         d
# 0  0.679143  0.318726  0.064257  0.255853
# 1  0.708944  0.944984  0.011668  0.353737
# 2  0.143034  0.187228  0.213950  0.200653
# 3  0.155086  0.537376  0.948629  0.923996
# 4  0.155418  0.015630  0.594991  0.731080

# %%
df.plot.scatter(x="a", y="b")

# %%
ax = df.plot.scatter(x="a", y="b", color="DarkBlue", label="Grupo 1")
df.plot.scatter(x="c", y="d", color="DarkGreen", label="Grupo 2", ax=ax)

# %%
df.plot.scatter(x="a", y="b", c="c", s=50)

# %% [markdown]
# # Scatter Matrix Plot

# %%
from sklearn import datasets
from pandas.plotting import scatter_matrix

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['classe'] = iris.target
colors = df.classe.apply(lambda c: {0: 'b', 1: 'g', 2: 'r'}[c])

scatter_matrix(df.iloc[:, :-1], figsize=(10, 10), c=colors);
